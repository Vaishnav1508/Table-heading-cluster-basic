# %%
import pytesseract
from pytesseract import Output
import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import time

# %%
filepath="Text column name extraction/e1.jpg"
img = Image.open(filepath).convert('L')
WIDTH, HEIGHT = img.size
#print("1:::",WIDTH,HEIGHT,":::1")
pix = img.load()
#print("1:::",pix,":::1")
data = np.asarray(img.getdata())
#print("1:::",data,":::1")
data = data.reshape((HEIGHT,WIDTH))
#print("1:::",data,":::1")
fig,ax = plt.subplots()
reduced_data = data.mean(axis=0)
#print("1:::",reduced_data,":::1")
ax.plot(reduced_data)
plt.show()
plt.imshow(img)
reduced_data,WIDTH,HEIGHT
# Out:
# (array([156., 156., 156., ..., 156., 156., 156.]), 1367, 47)
